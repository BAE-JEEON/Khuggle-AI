# %% [markdown]
# ## mmsr

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %% [markdown]
# GitHub: https://github.com/pinggoo17/competition

# %%
# !git clone https://github.com/pinggoo17/competition.git
# Out:
# Cloning into 'competition'...
# remote: Enumerating objects: 462, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 462 (delta 0), reused 0 (delta 0), pack-reused 461
# Receiving objects: 100% (462/462), 48.11 MiB | 17.31 MiB/s, done.
# Resolving deltas: 100% (71/71), done.
# Checking out files: 100% (382/382), done.

# %% [markdown]
# Pleaes download mmsr_SRResNet_pretrain.pth [here](https://github.com/XPixelGroup/RankSRGAN).<br/>
# After downloading pre-trained weights, please put it in competition/KHUGGLE/experiments/pretrained_models.

# %%
cd /content/drive/MyDrive/competition/KHUGGLE/MODEL_mmsr/codes
# Out:
# /content/drive/MyDrive/competition/KHUGGLE/MODEL_mmsr/codes

# %% [markdown]
# After runnign following code, the results images will be in the /np2img
#
# contact: kikitank1@khu.ac.kr

# %%
# !python test.py -opt options/test/test_RankSRGAN.yml
# Out:
# torch.cuda.is_available():  True
# export CUDA_VISIBLE_DEVICES=0
# 22-12-08 07:41:17.851 - INFO:   name: mmsr_SRResNet_pretrain
#   suffix: None
#   model: sr
#   distortion: sr
#   scale: 4
#   crop_border: None
#   gpu_ids: [0]
#   datasets:[
#     test_1:[
#       name: KHUGGLE
#       mode: LQGT
#       dataroot_GT: /content/drive/MyDrive/competition/KHUGGLE/MODEL_mmsr/datasets/KHUGGLE
#       dataroot_LQ: None
#       phase: test
#       scale: 4
#       data_type: img
#     ]
#   ]
#   network_G:[
#     which_model_G: SRResNet
#     in_nc: 3
#     out_nc: 3
#     nf: 64
#     nb: 16
#     upscale: 1
#     scale: 4
#   ]
#   path:[
#     pretrain_model_G: ../experiments/pretrained_models/mmsr_SRResNet_pretrain.pth
#     root: /content/drive/MyDrive/competition/KHUGGLE/MODEL_mmsr
#     results_root: /content/drive/MyDrive/competition/KHUGGLE/MODEL_mmsr/results/mmsr_SRResNet_pretrain
#     log: /content/drive/MyDrive/competition/KHUGGLE/MODEL_mmsr/results/mmsr_SRResNet_pretrain
# ...

# %%
cd /content/drive/MyDrive/competition/KHUGGLE/MODEL_mmsr/img2np
# Out:
# /content/drive/MyDrive/competition/KHUGGLE/MODEL_mmsr/img2np

# %%
# !python trans2sub.py
# Out:
# infer_dataset:  ['0001.png', '0002.png', '0003.png', '0004.png', '0005.png', '0006.png', '0007.png', '0008.png', '0009.png', '0010.png', '0011.png', '0012.png', '0013.png', '0014.png', '0015.png', '0016.png', '0017.png', '0018.png', '0019.png', '0020.png', '0021.png', '0022.png', '0023.png', '0024.png', '0025.png', '0026.png', '0027.png', '0028.png', '0029.png', '0030.png']
# 0001.png
# (144, 248, 3)
# (580, 1000, 3)
# 0002.png
# (164, 248, 3)
# (664, 1000, 3)
# 0003.png
# (164, 248, 3)
# (664, 1000, 3)
# 0004.png
# (164, 248, 3)
# (664, 1000, 3)
# 0005.png
# (164, 248, 3)
# (664, 1000, 3)
# 0006.png
# (144, 248, 3)
# (588, 1000, 3)
# 0007.png
# (164, 248, 3)
# (664, 1000, 3)
# 0008.png
# (196, 300, 3)
# (796, 1200, 3)
# 0009.png
# (164, 248, 3)
# (664, 1000, 3)
# 0010.png
# (164, 248, 3)
# (664, 1000, 3)
# 0011.png
# (164, 248, 3)
# (664, 1000, 3)
# 0012.png
# (164, 248, 3)
# (664, 1000, 3)
# 0013.png
# (164, 248, 3)
# (664, 1000, 3)
# 0014.png
# (164, 248, 3)
# (664, 1000, 3)
# ...

# %%
cd /content/drive/MyDrive/competition/KHUGGLE/MODEL_mmsr/np2img
# Out:
# /content/drive/MyDrive/competition/KHUGGLE/MODEL_mmsr/np2img

# %%
# !python tr.py
# Out:
# (580, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (588, 1000, 3)
# (664, 1000, 3)
# (796, 1200, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (536, 1200, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
# (664, 1000, 3)
